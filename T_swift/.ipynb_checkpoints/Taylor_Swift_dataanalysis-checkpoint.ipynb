# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('Taylor Swift Spotify Data 07-23.csv')

# %%
df.head()
# Out:
#     artist_name               artist_id                album_id album_type  \
# 0  Taylor Swift  06HL4z0CvFAxyc27GXpf02  5AEDGbliTTfjOB8TSm1sxt      album
# 1  Taylor Swift  06HL4z0CvFAxyc27GXpf02  5AEDGbliTTfjOB8TSm1sxt      album
# 2  Taylor Swift  06HL4z0CvFAxyc27GXpf02  5AEDGbliTTfjOB8TSm1sxt      album
# 3  Taylor Swift  06HL4z0CvFAxyc27GXpf02  5AEDGbliTTfjOB8TSm1sxt      album
# 4  Taylor Swift  06HL4z0CvFAxyc27GXpf02  5AEDGbliTTfjOB8TSm1sxt      album
#
#   album_release_date  album_release_year album_release_date_precision  \
# 0         2023-07-07                2023                          day
# 1         2023-07-07                2023                          day
# 2         2023-07-07                2023                          day
# 3         2023-07-07                2023                          day
# 4         2023-07-07                2023                          day
#
#    danceability  energy  key  ...                           track_name  \
# 0         0.646   0.783    7  ...              Mine (Taylor's Version)
# 1         0.588   0.758    5  ...        Sparks Fly (Taylor’s Version)
# 2         0.497   0.635    2  ...  Back To December (Taylor's Version)
# 3         0.727   0.677    7  ...         Speak Now (Taylor's Version)
# 4         0.419   0.470    4  ...         Dear John (Taylor's Version)
#
#    track_preview_url  track_number   type  \
# 0                NaN             1  track
# 1                NaN             2  track
# 2                NaN             3  track
# 3                NaN             4  track
# 4                NaN             5  track
#
#                               track_uri  \
# 0  spotify:track:7G0gBu6nLdhFDPRLc0HdDG
# 1  spotify:track:3MytWN8L7shNYzGl4tAKRp
# 2  spotify:track:79uDOz0zuuWS7HWxzMmTa2
# 3  spotify:track:5xXqyjLicvEpch72qEryFT
# 4  spotify:track:1zU8j1x3yi9xalMF96pzKp
#
#                                external_urls.spotify  \
# 0  https://open.spotify.com/track/7G0gBu6nLdhFDPR...
# 1  https://open.spotify.com/track/3MytWN8L7shNYzG...
# 2  https://open.spotify.com/track/79uDOz0zuuWS7HW...
# 3  https://open.spotify.com/track/5xXqyjLicvEpch7...
# 4  https://open.spotify.com/track/1zU8j1x3yi9xalM...
#
#                      album_name  key_name mode_name key_mode
# 0  Speak Now (Taylor's Version)         G     major  G major
# 1  Speak Now (Taylor's Version)         F     major  F major
# 2  Speak Now (Taylor's Version)         D     major  D major
# 3  Speak Now (Taylor's Version)         G     major  G major
# 4  Speak Now (Taylor's Version)         E     major  E major
#
# [5 rows x 36 columns]

# %%
df.groupby(['album_name']).size()
# Out:
# album_name
# 1989                                                                                   13
# 1989 (Deluxe)                                                                          19
# Fearless (International Version)                                                       16
# Fearless (Platinum Edition)                                                            19
# Fearless (Taylor's Version)                                                            26
# Live From Clear Channel Stripped 2008                                                   8
# Lover                                                                                  18
# Midnights                                                                              13
# Midnights (3am Edition)                                                                20
# Midnights (The Til Dawn Edition)                                                       23
# Red (Deluxe Edition)                                                                   22
# Red (Taylor's Version)                                                                 30
# Speak Now                                                                              14
# Speak Now (Deluxe Package)                                                             22
# Speak Now (Taylor's Version)                                                           22
# Speak Now World Tour Live                                                              16
# Taylor Swift                                                                           15
# evermore                                                                               15
# evermore (deluxe version)                                                              17
# folklore                                                                               16
# folklore (deluxe version)                                                              17
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]    34
# reputation                                                                             15
# reputation Stadium Tour Surprise Song Playlist                                         46
# dtype: int64

# %%
df_small=df.drop(['type','track_href','artist_id', 'album_id', 'album_release_date_precision','track_preview_url', 'track_uri', 'external_urls.spotify'], axis=1)

# filter the rows that contain the substring, this is to remove entries which aren't original albums but special renditions and such
substring = ['Deluxe','Disney','Edition', 'Live','Stadium','delux','International']
pattern = '|'.join(substring)

filter = df_small['album_name'].str.contains(pattern) 
filtered_df = df_small[~filter]

filtered_df['album_name'].unique()
# Out:
# array(["Speak Now (Taylor's Version)", 'Midnights',
#        "Red (Taylor's Version)", "Fearless (Taylor's Version)",
#        'evermore', 'folklore', 'Lover', 'reputation', '1989', 'Speak Now',
#        'Taylor Swift'], dtype=object)

# %%
filtered_df=filtered_df.drop_duplicates(subset='track_name')
filtered_df.head()
# Out:
#     artist_name album_type album_release_date  album_release_year  \
# 0  Taylor Swift      album         2023-07-07                2023
# 1  Taylor Swift      album         2023-07-07                2023
# 2  Taylor Swift      album         2023-07-07                2023
# 3  Taylor Swift      album         2023-07-07                2023
# 4  Taylor Swift      album         2023-07-07                2023
#
#    danceability  energy  key  loudness  mode  speechiness  ...  disc_number  \
# 0         0.646   0.783    7    -2.846     1       0.0356  ...            1
# 1         0.588   0.758    5    -2.347     1       0.0305  ...            1
# 2         0.497   0.635    2    -3.927     1       0.0273  ...            1
# 3         0.727   0.677    7    -2.871     1       0.0325  ...            1
# 4         0.419   0.470    4    -5.016     1       0.0296  ...            1
#
#    duration_ms  explicit  is_local                           track_name  \
# 0       231706     False     False              Mine (Taylor's Version)
# 1       261230     False     False        Sparks Fly (Taylor’s Version)
# 2       294189     False     False  Back To December (Taylor's Version)
# 3       242473     False     False         Speak Now (Taylor's Version)
# 4       405906     False     False         Dear John (Taylor's Version)
#
#   track_number                    album_name  key_name  mode_name  key_mode
# 0            1  Speak Now (Taylor's Version)         G      major   G major
# 1            2  Speak Now (Taylor's Version)         F      major   F major
# 2            3  Speak Now (Taylor's Version)         D      major   D major
# 3            4  Speak Now (Taylor's Version)         G      major   G major
# 4            5  Speak Now (Taylor's Version)         E      major   E major
#
# [5 rows x 28 columns]

# %%
print(filtered_df['album_name'].unique())
print(filtered_df.groupby(['album_name'])['duration_ms'].sum().keys())
# Out:
# ["Speak Now (Taylor's Version)" 'Midnights' "Red (Taylor's Version)"
#  "Fearless (Taylor's Version)" 'evermore' 'folklore' 'Lover' 'reputation'
#  '1989' 'Speak Now' 'Taylor Swift']
# Index(['1989', 'Fearless (Taylor's Version)', 'Lover', 'Midnights',
#        'Red (Taylor's Version)', 'Speak Now', 'Speak Now (Taylor's Version)',
#        'Taylor Swift', 'evermore', 'folklore', 'reputation'],
#       dtype='object', name='album_name')

# %%
# filtered_df['album_name'].unique() and filtered_df.groupby(['album_name'])['speechiness'].min().keys() does not have the same ordering
#filtered_df['album_name'].unique() preserves order of appearence 
# filtered_df.groupby(['album_name'])['speechiness'].min().keys() is ordered like the rest of the functions used here
album_summary=pd.DataFrame()
album_summary['album']=filtered_df.groupby(['album_name'])['speechiness'].min().keys()
album_summary['size']=list(filtered_df.groupby(['album_name']).size())
album_summary['speechiness_min']=list(filtered_df.groupby(['album_name'])['speechiness'].min())
album_summary['speechiness_max']=list(filtered_df.groupby(['album_name'])['speechiness'].max())
album_summary['loudness_min']=list(filtered_df.groupby(['album_name'])['loudness'].min())
album_summary['loudness_max']=list(filtered_df.groupby(['album_name'])['loudness'].max())
album_summary['total_duration_ms']=list(filtered_df.groupby(['album_name'])['duration_ms'].sum())
album_summary['total_duration_HMS'] = pd.to_datetime(album_summary['total_duration_ms'], unit='ms').dt.strftime('%H:%M:%S:%f').str[:-3] 
album_summary
# Out:
#                            album  size  speechiness_min  speechiness_max  \
# 0                           1989    13           0.0324           0.1810
# 1    Fearless (Taylor's Version)    26           0.0263           0.0628
# 2                          Lover    18           0.0344           0.5190
# 3                      Midnights    13           0.0375           0.3900
# 4         Red (Taylor's Version)    30           0.0250           0.1750
# 5                      Speak Now    14           0.0258           0.0887
# 6   Speak Now (Taylor's Version)    22           0.0265           0.0803
# 7                   Taylor Swift    15           0.0231           0.0646
# 8                       evermore    15           0.0264           0.2450
# 9                       folklore    16           0.0253           0.0916
# 10                    reputation    15           0.0354           0.1960
#
#     loudness_min  loudness_max  total_duration_ms total_duration_HMS
# 0         -8.768        -4.807            2927864       00:48:47:864
# 1        -11.548        -3.669            6392490       01:46:32:490
# 2        -12.566        -4.105            3711381       01:01:51:381
# 3        -15.480        -6.571            2648338       00:44:08:338
# 4        -13.778        -4.516            7839830       02:10:39:830
# 5         -9.531        -2.641            4021982       01:07:01:982
# 6         -8.460        -1.909            6284051       01:44:44:051
# 7         -6.941        -2.098            3209567       00:53:29:567
# 8        -12.077        -7.589            3645210       01:00:45:210
# 9        -15.065        -6.942            3816587       01:03:36:587
# 10       -12.864        -5.986            3345300       00:55:45:300

# %%
album_summary=pd.DataFrame()
temp_df['album']=album_summary['album']
temp_df['total_duration_ms']=album_summary['total_duration_ms']
temp_df.plot.barh(x='a', y='b')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 album_summary=pd.DataFrame()
# ----> 2 temp_df['album']=album_summary['album']
#       3 temp_df['total_duration_ms']=album_summary['total_duration_ms']
#       4 temp_df.plot.barh(x='a', y='b')
#
# File ~/physics_codes/anaconda3/anaconda3/envs/pheno/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/physics_codes/anaconda3/anaconda3/envs/pheno/lib/python3.10/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'album'

# %%
plt.rcParams['figure.figsize'] = [6, 6]
plt.yticks([])
plt.xticks(np.arange(1+0.5/(11/12),12+0.5/(11/12),11/12), ('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'))
filtered_data_ym['time'].dt.month.hist(bins=12)
plt.title('2024 monthly histogram')
plt.show()

# %%
plt.rcParams['figure.figsize'] = [6, 6]
plt.xticks(np.arange(1,23,2))
filtered_data_ym['time'].dt.hour.hist(bins=24)
plt.title('2024 hourly histogram')
plt.show()

# %%
filtered_data_ym.head()
# Out:
#            header                                              title  \
# 42  YouTube Music       Watched hoax (the long pond studio sessions)
# 43  YouTube Music      Watched peace (the long pond studio sessions)
# 44  YouTube Music      Watched betty (the long pond studio sessions)
# 45  YouTube Music   Watched epiphany (the long pond studio sessions)
# 52  YouTube Music  Watched mad woman (the long pond studio sessions)
#
#                                          titleUrl  \
# 42  https://music.youtube.com/watch?v=UwTe12OQs0w
# 43  https://music.youtube.com/watch?v=EXjrfW8TTls
# 44  https://music.youtube.com/watch?v=HmwlDOzoalU
# 45  https://music.youtube.com/watch?v=DMLiwF_lqMg
# 52  https://music.youtube.com/watch?v=9tu07LiIuhM
#
#                                             subtitles  \
# 42  [{'name': 'Taylor Swift - Topic', 'url': 'http...
# 43  [{'name': 'Taylor Swift - Topic', 'url': 'http...
# 44  [{'name': 'Taylor Swift - Topic', 'url': 'http...
# 45  [{'name': 'Taylor Swift - Topic', 'url': 'http...
# 52  [{'name': 'Taylor Swift - Topic', 'url': 'http...
#
#                                time   products         activityControls  \
# 42 2024-12-06 17:08:21.072000+00:00  [YouTube]  [YouTube watch history]
# 43 2024-12-06 17:04:46.868000+00:00  [YouTube]  [YouTube watch history]
# 44 2024-12-06 16:59:56.277000+00:00  [YouTube]  [YouTube watch history]
# 45 2024-12-06 16:59:54.670000+00:00  [YouTube]  [YouTube watch history]
# 52 2024-12-06 15:39:13.512000+00:00  [YouTube]  [YouTube watch history]
#
#    description details
# 42         NaN     NaN
# 43         NaN     NaN
# 44         NaN     NaN
# 45         NaN     NaN
# 52         NaN     NaN

# %%
musicdata=df.loc[df['header'] != 'YouTube']

# %%
musicdata.columns
# Out:
# Index(['header', 'title', 'titleUrl', 'subtitles', 'time', 'products',
#        'activityControls', 'description', 'details'],
#       dtype='object')

# %%
musicdata2024 = musicdata.loc[musicdata['time']>= '2024-01-01']
artists = [musicdata2024['subtitles'][key][0]['name'].replace(' - Topic', '') for key in musicdata2024['subtitles'].keys()]
listenedlist_track = [element.replace('Watched', '').split('(')[0] for element in list(musicdata2024['title'][key] for key in musicdata2024['title'].keys())]
#listenedlist_album = [element.replace('Watched', '').split('(') for element in list(musicdata2024['title'][key] for key in musicdata2024['title'].keys())]
#print(listenedlist_track[:20])
# Out:
# [' hoax ', ' peace ', ' betty ', ' epiphany ', ' mad woman ', ' invisible string ', ' illicit affairs ', ' this is me trying ', ' august ', ' seven ', ' mirrorball ', ' my tears ricochet ', ' exile ', ' the last great american dynasty ', ' cardigan ', ' the 1 ', ' the lakes ', ' hoax', ' peace', ' betty']

# %%
dummyframe = musicdata2024.copy()
dummyframe['artist'] = artists
artist_totals=dummyframe.groupby(['artist']).size().reset_index(name='Play counts')
top = artist_totals.sort_values('Play counts', ascending=False).set_index('artist')[0:18]
print(top)
# Out:
#                     Play counts
# artist
# Taylor Swift               2194
# Ed Sheeran                  186
# Daft Punk                   151
# Miley Cyrus                 141
# Harry Styles                141
# Olivia Rodrigo              133
# Christina Aguilera          117
# Dua Lipa                    111
# One Direction               108
# Lizzo                        93
# Maroon 5                     76
# Black Eyed Peas              73
# Justin Timberlake            73
# Lady Gaga                    73
# Katy Perry                   69
# Outkast                      69
# Mary J. Blige                68
# Queen                        67
